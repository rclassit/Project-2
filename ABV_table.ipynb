# %%
import pandas as pd

# %%
# URL of page to be scraped
url = 'http://www.alcoholcontents.com/liquor/'

# %%
abv_table = pd.read_html(url)
abv_table
# Out:
# [              Liquor / Cocktail / Liqueur  % Alc (ABV)    Cal
#  0                                Advocaat           17    NaN
#  1                              Aftershock           30    NaN
#  2            Aftershock Cinnamon Schnapps           40  103.0
#  3    Aftershock Cool Citrus Mint Schnapps           40   72.0
#  4                             Aguardiente           30    NaN
#  ..                                    ...          ...    ...
#  114                       Wallace Liqueur           35    NaN
#  115                             Xtabentún           40    NaN
#  116                     Yellow Chartreuse           40    NaN
#  117                        Yellow Curaçao           31    NaN
#  118                            Yukon Jack           50   69.0
#
#  [119 rows x 3 columns]]

# %%
abv_df = abv_table[0]
abv_df.head(20)
# Out:
#              Liquor / Cocktail / Liqueur  % Alc (ABV)    Cal
# 0                               Advocaat           17    NaN
# 1                             Aftershock           30    NaN
# 2           Aftershock Cinnamon Schnapps           40  103.0
# 3   Aftershock Cool Citrus Mint Schnapps           40   72.0
# 4                            Aguardiente           30    NaN
# 5                                Amadeus            5    NaN
# 6                               Amaretto           28  110.0
# 7                    Amaretto Di Saronno           28  110.0
# 8                                  Amaro           17    NaN
# 9                                Amarula           17    NaN
# 10                     American Schnapps           40    NaN
# 11                         Anis del Toro           30    NaN
# 12                              Anisette           30  100.0
# 13                                  Arak           50    NaN
# 14                          Ashanti Gold           17    NaN
# 15                                 Aurum           40  103.0
# 16                   Baileys Irish Cream           17  117.0
# 17                            Bärenjäger           35  103.0
# 18                            Becherovka           38  135.0
# 19                                Beirão           22    NaN

# %%
# Remove Cal column
abv_df_clean = abv_df.drop(['Cal'], axis=1)
abv_df_clean.head()
# Out:
#             Liquor / Cocktail / Liqueur  % Alc (ABV)
# 0                              Advocaat           17
# 1                            Aftershock           30
# 2          Aftershock Cinnamon Schnapps           40
# 3  Aftershock Cool Citrus Mint Schnapps           40
# 4                           Aguardiente           30

# %%
#Rename columns
renamed_df = abv_df_clean.rename(columns={"Liquor / Cocktail / Liqueur":"spirit", "% Alc (ABV)":"abv"})
renamed_df.head()
# Out:
#                                  spirit  abv
# 0                              Advocaat   17
# 1                            Aftershock   30
# 2          Aftershock Cinnamon Schnapps   40
# 3  Aftershock Cool Citrus Mint Schnapps   40
# 4                           Aguardiente   30

# %%
# Add Common Spirits list to dataframe in ascending order (alphabetical); getting the mean of the abv range.
# !!!!---May have to add more as we work through the data that Kelly is cleaning.

common_spirits = [{"spirit": "Absinthe", "abv": 60},
                {"spirit": "Baijiu", "abv": 47},
                {"spirit": "Bourbon", "abv": 65},
                {"spirit": "Brandy", "abv": 42},
                {"spirit": "Everclear", "abv": 85},
                {"spirit": "Gin", "abv": 37},
                {"spirit": "Grappa", "abv": 47},
                {"spirit": "Rum", "abv": 47},
                {"spirit": "Sake", "abv": 15},
                {"spirit": "Tequila", "abv": 45},
                {"spirit": "Vodka", "abv": 42},
                {"spirit": "Whisky", "abv": 46},
                {"spirit": "German Schnapps", "abv": 30}]

spirits_df = pd.DataFrame(common_spirits)
spirits_df

# Fine mean of %Alc ranges
# Out:
#              spirit  abv
# 0          Absinthe   60
# 1            Baijiu   47
# 2           Bourbon   65
# 3            Brandy   42
# 4         Everclear   85
# 5               Gin   37
# 6            Grappa   47
# 7               Rum   47
# 8              Sake   15
# 9           Tequila   45
# 10            Vodka   42
# 11           Whisky   46
# 12  German Schnapps   30

# %%
# Merge spirits_df and abv_df
merge_df = pd.merge(renamed_df, spirits_df, on=["spirit", "abv"], how="outer")
merge_df



# merge %Alc columns
# Out:
#                                    spirit  abv
# 0                                Advocaat   17
# 1                              Aftershock   30
# 2            Aftershock Cinnamon Schnapps   40
# 3    Aftershock Cool Citrus Mint Schnapps   40
# 4                             Aguardiente   30
# ..                                    ...  ...
# 127                                  Sake   15
# 128                               Tequila   45
# 129                                 Vodka   42
# 130                                Whisky   46
# 131                       German Schnapps   30
#
# [132 rows x 2 columns]

# %%
renamed_df.dtypes
# Out:
# spirit    object
# abv        int64
# dtype: object

# %%
spirits_df.dtypes
# Out:
# spirit    object
# abv        int64
# dtype: object

# %%
# Sort ascending
abv_sort_df = merge_df.sort_values("spirit")
abv_sort_df.head(50)
# Out:
#                                    spirit  abv
# 119                              Absinthe   60
# 0                                Advocaat   17
# 1                              Aftershock   30
# 2            Aftershock Cinnamon Schnapps   40
# 3    Aftershock Cool Citrus Mint Schnapps   40
# 4                             Aguardiente   30
# 5                                 Amadeus    5
# 6                                Amaretto   28
# 7                     Amaretto Di Saronno   28
# 8                                   Amaro   17
# 9                                 Amarula   17
# 10                      American Schnapps   40
# 11                          Anis del Toro   30
# 12                               Anisette   30
# 13                                   Arak   50
# 14                           Ashanti Gold   17
# 15                                  Aurum   40
# 120                                Baijiu   47
# 16                    Baileys Irish Cream   17
# 18                             Becherovka   38
# 19                                 Beirão   22
# 20                            Benedictine   40
# 21                           Blue Curaçao   30
# 121                               Bourbon   65
# 122                                Brandy   42
# 17                             Bärenjäger   35
# 22                                Calisay   20
# 23                                 Canton   28
# 24                               Chambord   17
# 25                             Chartreuse   55
# 26                         Cherry Heering   22
# 27                     Cloudberry Liqueur   25
# 28                            Coconut Rum   21
# 29                              Cointreau   40
# 30                        Crème de Banane   30
# 31                         Crème de Cacao   25
# 32                        Crème de Cassis   20
# 33                        Crème de Cerise   20
# 34                        Crème de Menthe   25
# 35                      Crème de Myrtille   20
# 36                        Crème de Noyaux   30
# 37                          Crème de Rose   18
# 38                      Crème de Violette   25
# 39                       Crème de Y'vette   28
# 40                                Curaçao   30
# 41                                  Cynar   17
# 42                                Damiana   50
# 43                               Destinée   17
# 44                               Drambuie   40
# 45        Drumgray Highland Cream Liqueur   17

# %%
# # Dataframe to HTML
# abv_html_table = abv_sort_df.to_html()
# abv_html_table

# %%
# abv_html_table.replace('\n', '')

# %%
abv_sort_df.to_csv("abv_sort.csv", index=False, header=True)

# %%
abv_sort_df.to_html('abv_table.html', index=False)
